# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import jax.numpy as jnp
from jax import grad
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-a6194d1c2aec> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import math
# ----> 4 import jax.numpy as jnp
#       5 from jax import grad
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/__init__.py in <module>
#     158 from jax import abstract_arrays as _deprecated_abstract_arrays
#     159 from jax import custom_derivatives as custom_derivatives
# --> 160 from jax import custom_batching as custom_batching
#     161 from jax import custom_transpose as custom_transpose
#     162 from jax import api_util as api_util
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/custom_batching.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from jax._src.custom_batching import (
#      16   custom_vmap,
#      17   sequential_vmap,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/custom_batching.py in <module>
#      17 from typing import Callable, Optional
#      18
# ---> 19 from jax import lax
#      20 from jax._src import api
#      21 from jax._src import core
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/lax/__init__.py in <module>
#     367 )
#     368 from jax._src.ad_util import stop_gradient_p as stop_gradient_p
# --> 369 from jax.lax import linalg as linalg
#     370
#     371 from jax._src.pjit import with_sharding_constraint as with_sharding_constraint
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/lax/linalg.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from jax._src.lax.linalg import (
#      16   cholesky,
#      17   cholesky_p,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/linalg.py in <module>
#      35 from jax._src.interpreters import mlir
#      36 from jax._src.lax import control_flow
# ---> 37 from jax._src.lax import eigh as lax_eigh
#      38 from jax._src.lax import lax as lax_internal
#      39 from jax._src.lax import svd as lax_svd
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/eigh.py in <module>
#      37 from jax._src.numpy import ufuncs
#      38 from jax import lax
# ---> 39 from jax._src.lax import qdwh
#      40 from jax._src.lax import linalg as lax_linalg
#      41 from jax._src.lax.stack import Stack
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/qdwh.py in <module>
#      29
#      30 import jax
# ---> 31 import jax.numpy as jnp
#      32 from jax import lax
#      33 from jax._src import core
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/numpy/__init__.py in <module>
#     258 # minimum version.
#     259 import jax._src.numpy.lax_numpy
# --> 260 if hasattr(jax._src.numpy.lax_numpy, "int4"):
#     261   from jax._src.numpy.lax_numpy import (
#     262     int4 as int4,
#
# AttributeError: partially initialized module 'jax' has no attribute '_src' (most likely due to a circular import)

# %%
def f(x):
    return 1 + 0.5*math.tanh(2*x)

# Central difference method for numerical derivative
def central_difference(x, h=1e-5):
    return (f(x + h) - f(x - h)) / (2 * h)

def analytic_der(x):
    return 1/(math.cosh(2*x)**2)

# %%
# Generate x values in the range -2 <= x <= 2
x_values = np.linspace(-2, 2, 100)


# Compute numerical and analytic derivatives
numerical_derivative = [central_difference(x) for x in x_values]
analytic_derivative = [analytic_der(x) for x in x_values]

# %%
# Plot the results
plt.figure(figsize = [10,6] )
plt.plot(x_values, analytic_derivative, label='Analytic Derivative', color='blue', linestyle='-')
plt.plot(x_values, numerical_derivative, label='Numerical Derivative', color='red', linestyle='None', marker='o')

plt.title('Numerical vs Analytic Derivative of f(x) = 1 + tanh(2x)')
plt.xlabel('x')
plt.ylabel('Derivative f\'(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import jax
def f_jax(x):
    return 1 + np.tanh(2 * x)

# Autodiff using JAX
f_prime_autodiff = jax.grad(f_jax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-0dda28674167> in <module>
# ----> 1 import jax
#       2 def f_jax(x):
#       3     return 1 + np.tanh(2 * x)
#       4
#       5 # Autodiff using JAX
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/__init__.py in <module>
#     158 from jax import abstract_arrays as _deprecated_abstract_arrays
#     159 from jax import custom_derivatives as custom_derivatives
# --> 160 from jax import custom_batching as custom_batching
#     161 from jax import custom_transpose as custom_transpose
#     162 from jax import api_util as api_util
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/custom_batching.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from jax._src.custom_batching import (
#      16   custom_vmap,
#      17   sequential_vmap,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/custom_batching.py in <module>
#      17 from typing import Callable, Optional
#      18
# ---> 19 from jax import lax
#      20 from jax._src import api
#      21 from jax._src import core
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/lax/__init__.py in <module>
#     367 )
#     368 from jax._src.ad_util import stop_gradient_p as stop_gradient_p
# --> 369 from jax.lax import linalg as linalg
#     370
#     371 from jax._src.pjit import with_sharding_constraint as with_sharding_constraint
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/lax/linalg.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from jax._src.lax.linalg import (
#      16   cholesky,
#      17   cholesky_p,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/linalg.py in <module>
#      35 from jax._src.interpreters import mlir
#      36 from jax._src.lax import control_flow
# ---> 37 from jax._src.lax import eigh as lax_eigh
#      38 from jax._src.lax import lax as lax_internal
#      39 from jax._src.lax import svd as lax_svd
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/eigh.py in <module>
#      37 from jax._src.numpy import ufuncs
#      38 from jax import lax
# ---> 39 from jax._src.lax import qdwh
#      40 from jax._src.lax import linalg as lax_linalg
#      41 from jax._src.lax.stack import Stack
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/_src/lax/qdwh.py in <module>
#      29
#      30 import jax
# ---> 31 import jax.numpy as jnp
#      32 from jax import lax
#      33 from jax._src import core
#
# ~/opt/anaconda3/lib/python3.8/site-packages/jax/numpy/__init__.py in <module>
#     258 # minimum version.
#     259 import jax._src.numpy.lax_numpy
# --> 260 if hasattr(jax._src.numpy.lax_numpy, "int4"):
#     261   from jax._src.numpy.lax_numpy import (
#     262     int4 as int4,
#
# AttributeError: partially initialized module 'jax' has no attribute '_src' (most likely due to a circular import)
